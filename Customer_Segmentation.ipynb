# %% [markdown]
# ## Problem Statement
# An online retail store is try to understand the various customer purchase patterns their firm, you are required to give enough evidence insights to provide the same.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Gatering Data

# %%
df=pd.read_csv('OnlineRetail (5).csv',encoding='unicode_escape')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df=df[['CustomerID','InvoiceNo','StockCode','Quantity','UnitPrice','Description','InvoiceDate','Country']]
df.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  \
# 0     17850.0    536365    85123A         6       2.55
# 1     17850.0    536365     71053         6       3.39
# 2     17850.0    536365    84406B         8       2.75
# 3     17850.0    536365    84029G         6       3.39
# 4     17850.0    536365    84029E         6       3.39
#
#                            Description     InvoiceDate         Country
# 0   WHITE HANGING HEART T-LIGHT HOLDER  12/1/2010 8:26  United Kingdom
# 1                  WHITE METAL LANTERN  12/1/2010 8:26  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER  12/1/2010 8:26  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  12/1/2010 8:26  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART.  12/1/2010 8:26  United Kingdom

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
Total_amt=df['Quantity']*df['UnitPrice']
df.insert(loc=5,column='Total',value=Total_amt)

# %%
df.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0     17850.0    536365    85123A         6       2.55  15.30
# 1     17850.0    536365     71053         6       3.39  20.34
# 2     17850.0    536365    84406B         8       2.75  22.00
# 3     17850.0    536365    84029G         6       3.39  20.34
# 4     17850.0    536365    84029E         6       3.39  20.34
#
#                            Description     InvoiceDate         Country
# 0   WHITE HANGING HEART T-LIGHT HOLDER  12/1/2010 8:26  United Kingdom
# 1                  WHITE METAL LANTERN  12/1/2010 8:26  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER  12/1/2010 8:26  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  12/1/2010 8:26  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART.  12/1/2010 8:26  United Kingdom

# %%
country_price=df.groupby('Country')['Quantity'].sum().sort_values(ascending=False)

# %% [markdown]
# Analysis

# %%
country_price
# Out:
# Country
# United Kingdom          4263829
# Netherlands              200128
# EIRE                     142637
# Germany                  117448
# France                   110480
# Australia                 83653
# Sweden                    35637
# Switzerland               30325
# Spain                     26824
# Japan                     25218
# Belgium                   23152
# Norway                    19247
# Portugal                  16180
# Finland                   10666
# Channel Islands            9479
# Denmark                    8188
# Italy                      7999
# Cyprus                     6317
# Singapore                  5234
# Austria                    4827
# Hong Kong                  4769
# Israel                     4353
# Poland                     3653
# Unspecified                3300
# Canada                     2763
# Iceland                    2458
# Greece                     1556
# USA                        1034
# United Arab Emirates        982
# Malta                       944
# Lithuania                   652
# Czech Republic              592
# European Community          497
# Lebanon                     386
# Brazil                      356
# RSA                         352
# Bahrain                     260
# Saudi Arabia                 75
# Name: Quantity, dtype: int64

# %%
country_price[:5].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
time=pd.to_datetime(df['InvoiceDate'])
df['year']=time.dt.year
df.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0     17850.0    536365    85123A         6       2.55  15.30
# 1     17850.0    536365     71053         6       3.39  20.34
# 2     17850.0    536365    84406B         8       2.75  22.00
# 3     17850.0    536365    84029G         6       3.39  20.34
# 4     17850.0    536365    84029E         6       3.39  20.34
#
#                            Description     InvoiceDate         Country  year
# 0   WHITE HANGING HEART T-LIGHT HOLDER  12/1/2010 8:26  United Kingdom  2010
# 1                  WHITE METAL LANTERN  12/1/2010 8:26  United Kingdom  2010
# 2       CREAM CUPID HEARTS COAT HANGER  12/1/2010 8:26  United Kingdom  2010
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  12/1/2010 8:26  United Kingdom  2010
# 4       RED WOOLLY HOTTIE WHITE HEART.  12/1/2010 8:26  United Kingdom  2010

# %%
sales=df.groupby('year')['Total'].sum().plot(kind='bar')

# %%
new_df=df.copy()

# %%
new_df['month']=time.dt.month
new_df.groupby(['month','year'])['Total'].sum()
# Out:
# month  year
# 1      2011     560000.260
# 2      2011     498062.650
# 3      2011     683267.080
# 4      2011     493207.121
# 5      2011     723333.510
# 6      2011     691123.120
# 7      2011     681300.111
# 8      2011     682680.510
# 9      2011    1019687.622
# 10     2011    1070704.670
# 11     2011    1461756.250
# 12     2010     748957.020
#        2011     433668.010
# Name: Total, dtype: float64

# %% [markdown]
#  3.Clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.shape
# Out:
# (541909, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   CustomerID   406829 non-null  float64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   UnitPrice    541909 non-null  float64
#  5   Total        541909 non-null  float64
#  6   Description  540455 non-null  object
#  7   InvoiceDate  541909 non-null  object
#  8   Country      541909 non-null  object
#  9   year         541909 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 41.3+ MB

# %%
df_null = round(100*(df.isnull().sum())/len(df),2)
df_null
# Out:
# CustomerID     24.93
# InvoiceNo       0.00
# StockCode       0.00
# Quantity        0.00
# UnitPrice       0.00
# Total           0.00
# Description     0.27
# InvoiceDate     0.00
# Country         0.00
# year            0.00
# dtype: float64

# %%
df=df.dropna()
df.shape
# Out:
# (406829, 10)

# %%
df['CustomerID']=df['CustomerID'].astype(str)

# %%
plt.figure(figsize=(12,5))
sns.countplot(df['Country'],palette= 'Set3')
plt.xticks(rotation=40,ha='right')
plt.title("Country Distribution")
plt.xlabel('Country')
plt.ylabel('Count');

df
# Out:
#        CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0         17850.0    536365    85123A         6       2.55  15.30
# 1         17850.0    536365     71053         6       3.39  20.34
# 2         17850.0    536365    84406B         8       2.75  22.00
# 3         17850.0    536365    84029G         6       3.39  20.34
# 4         17850.0    536365    84029E         6       3.39  20.34
# ...           ...       ...       ...       ...        ...    ...
# 541904    12680.0    581587     22613        12       0.85  10.20
# 541905    12680.0    581587     22899         6       2.10  12.60
# 541906    12680.0    581587     23254         4       4.15  16.60
# 541907    12680.0    581587     23255         4       4.15  16.60
# 541908    12680.0    581587     22138         3       4.95  14.85
#
#                                 Description      InvoiceDate         Country  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER   12/1/2010 8:26  United Kingdom
# 1                       WHITE METAL LANTERN   12/1/2010 8:26  United Kingdom
# 2            CREAM CUPID HEARTS COAT HANGER   12/1/2010 8:26  United Kingdom
# 3       KNITTED UNION FLAG HOT WATER BOTTLE   12/1/2010 8:26  United Kingdom
# 4            RED WOOLLY HOTTIE WHITE HEART.   12/1/2010 8:26  United Kingdom
# ...                                     ...              ...             ...
# 541904          PACK OF 20 SPACEBOY NAPKINS  12/9/2011 12:50          France
# 541905         CHILDREN'S APRON DOLLY GIRL   12/9/2011 12:50          France
# 541906        CHILDRENS CUTLERY DOLLY GIRL   12/9/2011 12:50          France
# 541907      CHILDRENS CUTLERY CIRCUS PARADE  12/9/2011 12:50          France
# 541908        BAKING SET 9 PIECE RETROSPOT   12/9/2011 12:50          France
#
#         year
# 0       2010
# 1       2010
# 2       2010
# 3       2010
# 4       2010
# ...      ...
# 541904  2011
# 541905  2011
# 541906  2011
# 541907  2011
# 541908  2011
#
# [406829 rows x 10 columns]

# %%
df['Totalamt']=df['Quantity']*df['UnitPrice']

# %%
df.head()
# Out:
#   CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0    17850.0    536365    85123A         6       2.55  15.30
# 1    17850.0    536365     71053         6       3.39  20.34
# 2    17850.0    536365    84406B         8       2.75  22.00
# 3    17850.0    536365    84029G         6       3.39  20.34
# 4    17850.0    536365    84029E         6       3.39  20.34
#
#                            Description     InvoiceDate         Country  year  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER  12/1/2010 8:26  United Kingdom  2010
# 1                  WHITE METAL LANTERN  12/1/2010 8:26  United Kingdom  2010
# 2       CREAM CUPID HEARTS COAT HANGER  12/1/2010 8:26  United Kingdom  2010
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  12/1/2010 8:26  United Kingdom  2010
# 4       RED WOOLLY HOTTIE WHITE HEART.  12/1/2010 8:26  United Kingdom  2010
#
#    Totalamt
# 0     15.30
# 1     20.34
# 2     22.00
# 3     20.34
# 4     20.34

# %%
df.groupby('Country')['Totalamt'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
plt.figure(figsize=(8,5))
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'],errors='coerce')
sns.countplot(df['InvoiceDate'].dt.year,palette='Set1')
plt.xticks(rotation=40,ha='right')
plt.title('Year Distribution')
plt.xlabel('Year')
plt.ylabel('Count');

# %%
plt.figure(figsize=(8,5))
plt.xticks(rotation=40,ha='right')
sns.countplot(df['InvoiceDate'].dt.month_name(),palette='Spectral')
plt.title('Month Distribution')
plt.ylabel('Count')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.figure(figsize=(8,5))
plt.xticks(rotation=40,ha='right')
sns.countplot(df['InvoiceDate'].dt.day_name(),palette='Set1')
plt.title('Weekly Distribution')
plt.ylabel('Count')
plt.xlabel('Week Days')
# Out:
# Text(0.5, 0, 'Week Days')

# %% [markdown]
# Cleaning Data

# %%
rfm_m=df.groupby('CustomerID')['Totalamt'].sum()
rfm_m=rfm_m.reset_index()
rfm_m.head()
# Out:
#   CustomerID  Totalamt
# 0    12346.0      0.00
# 1    12347.0   4310.00
# 2    12348.0   1797.24
# 3    12349.0   1757.55
# 4    12350.0    334.40

# %%
rfm_f=df.groupby('CustomerID')['InvoiceNo'].count()
rfm_f=rfm_f.reset_index()
rfm_f.columns=['CustomerID','Frequency']
rfm_f.head()
# Out:
#   CustomerID  Frequency
# 0    12346.0          2
# 1    12347.0        182
# 2    12348.0         31
# 3    12349.0         73
# 4    12350.0         17

# %%
rfm=pd.merge(rfm_m,rfm_f, on='CustomerID', how='inner')
rfm.head()
# Out:
#   CustomerID  Totalamt  Frequency
# 0    12346.0      0.00          2
# 1    12347.0   4310.00        182
# 2    12348.0   1797.24         31
# 3    12349.0   1757.55         73
# 4    12350.0    334.40         17

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'],format='%d-%m-%y %H:%M')

# %%
max_date=df['InvoiceDate'].max()
max_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
df['Diff']=max_date-df['InvoiceDate']
df.head()
# Out:
#   CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0    17850.0    536365    85123A         6       2.55  15.30
# 1    17850.0    536365     71053         6       3.39  20.34
# 2    17850.0    536365    84406B         8       2.75  22.00
# 3    17850.0    536365    84029G         6       3.39  20.34
# 4    17850.0    536365    84029E         6       3.39  20.34
#
#                            Description         InvoiceDate         Country  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00  United Kingdom
# 1                  WHITE METAL LANTERN 2010-12-01 08:26:00  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00  United Kingdom
#
#    year  Totalamt              Diff
# 0  2010     15.30 373 days 04:24:00
# 1  2010     20.34 373 days 04:24:00
# 2  2010     22.00 373 days 04:24:00
# 3  2010     20.34 373 days 04:24:00
# 4  2010     20.34 373 days 04:24:00

# %%
rfm_p=df.groupby('CustomerID')['Diff'].min()
rfm_p=rfm_p.reset_index()
rfm_p.head()
# Out:
#   CustomerID              Diff
# 0    12346.0 325 days 02:33:00
# 1    12347.0   1 days 20:58:00
# 2    12348.0  74 days 23:37:00
# 3    12349.0  18 days 02:59:00
# 4    12350.0 309 days 20:49:00

# %%
import datetime as dt
rfm_p['Diff']=rfm_p['Diff'].dt.days
rfm_p.head()
# Out:
#   CustomerID  Diff
# 0    12346.0   325
# 1    12347.0     1
# 2    12348.0    74
# 3    12349.0    18
# 4    12350.0   309

# %%
rfm=pd.merge(rfm, rfm_p, on='CustomerID',how='inner')
rfm.columns=['CustomerID','Amount','Frequency','Recency']
rfm.head()
# Out:
#   CustomerID   Amount  Frequency  Recency
# 0    12346.0     0.00          2      325
# 1    12347.0  4310.00        182        1
# 2    12348.0  1797.24         31       74
# 3    12349.0  1757.55         73       18
# 4    12350.0   334.40         17      309

# %%
# Outlier Analysis of Amount Frequency and Recency

attributes = ['Amount','Frequency','Recency']
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data = rfm[attributes], orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
plt.ylabel("Range", fontweight = 'bold')
plt.xlabel("Attributes", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Attributes')

# %%
Q1 = rfm.Amount.quantile(0.05)
Q3 = rfm.Amount.quantile(0.95)
IQR = Q3 - Q1
rfm = rfm[(rfm.Amount >= Q1 - 1.5*IQR) & (rfm.Amount <= Q3 + 1.5*IQR)]

# Removing (statistical) outliers for Recency
Q1 = rfm.Recency.quantile(0.05)
Q3 = rfm.Recency.quantile(0.95)
IQR = Q3 - Q1
rfm = rfm[(rfm.Recency >= Q1 - 1.5*IQR) & (rfm.Recency <= Q3 + 1.5*IQR)]

# Removing (statistical) outliers for Frequency
Q1 = rfm.Frequency.quantile(0.05)
Q3 = rfm.Frequency.quantile(0.95)
IQR = Q3 - Q1
rfm = rfm[(rfm.Frequency >= Q1 - 1.5*IQR) & (rfm.Frequency <= Q3 + 1.5*IQR)]

# %%
rfm_df = rfm[['Amount', 'Frequency', 'Recency']]

# Instantiate
scaler = StandardScaler()

# fit_transform
rfm_df_scaled = scaler.fit_transform(rfm_df)
rfm_df_scaled.shape
# Out:
# (4293, 3)

# %%
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['Amount', 'Frequency', 'Recency']
rfm_df_scaled.head()
# Out:
#      Amount  Frequency   Recency
# 0 -0.723738  -0.752888  2.301611
# 1  1.731617   1.042467 -0.906466
# 2  0.300128  -0.463636 -0.183658
# 3  0.277517  -0.044720 -0.738141
# 4 -0.533235  -0.603275  2.143188

# %% [markdown]
# K-means Clustering

# %%
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([0, 2, 3, ..., 0, 3, 3])

# %%
ssd = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    ssd.append(kmeans.inertia_)
    
# plot the SSDs for each n_clusters
plt.plot(ssd, marker='o')
plt.title('Clusters Vs SSD')
plt.xlabel('No of Clusters')
plt.ylabel('Intertia')
# Out:
# Text(0, 0.5, 'Intertia')

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.5415858652525395
# For n_clusters=3, the silhouette score is 0.5084896296141937
# For n_clusters=4, the silhouette score is 0.4777820100216849
# For n_clusters=5, the silhouette score is 0.46627005641897035
# For n_clusters=6, the silhouette score is 0.41766919745832853
# For n_clusters=7, the silhouette score is 0.4152339794038324
# For n_clusters=8, the silhouette score is 0.40776912256990355

# %% [markdown]
# 4.Recommendation System based on product search

# %%
df['CustomerID'].nunique()
# Out:
# 4372

# %%
len(df['CustomerID'])
# Out:
# 406829

# %%
df1=df[{'Description','CustomerID'}]

# %%
df1.head()
# Out:
#                            Description CustomerID
# 0   WHITE HANGING HEART T-LIGHT HOLDER    17850.0
# 1                  WHITE METAL LANTERN    17850.0
# 2       CREAM CUPID HEARTS COAT HANGER    17850.0
# 3  KNITTED UNION FLAG HOT WATER BOTTLE    17850.0
# 4       RED WOOLLY HOTTIE WHITE HEART.    17850.0

# %%
customer={}

for i in df['Description']:
 if (i in customer.keys()):
        customer[i]+=1
 else:
    customer[i]=1

# %%
customer
# Out:
# {'WHITE HANGING HEART T-LIGHT HOLDER': 2070,
#  'WHITE METAL LANTERN': 259,
#  'CREAM CUPID HEARTS COAT HANGER': 250,
#  'KNITTED UNION FLAG HOT WATER BOTTLE': 330,
#  'RED WOOLLY HOTTIE WHITE HEART.': 333,
#  'SET 7 BABUSHKA NESTING BOXES': 306,
#  'GLASS STAR FROSTED T-LIGHT HOLDER': 129,
#  'HAND WARMER UNION JACK': 477,
#  'HAND WARMER RED POLKA DOT': 18,
#  'ASSORTED COLOUR BIRD ORNAMENT': 1418,
#  "POPPY'S PLAYHOUSE BEDROOM ": 329,
#  "POPPY'S PLAYHOUSE KITCHEN": 360,
#  'FELTCRAFT PRINCESS CHARLOTTE DOLL': 421,
#  'IVORY KNITTED MUG COSY ': 53,
#  'BOX OF 6 ASSORTED COLOUR TEASPOONS': 75,
#  'BOX OF VINTAGE JIGSAW BLOCKS ': 226,
#  'BOX OF VINTAGE ALPHABET BLOCKS': 236,
#  'HOME BUILDING BLOCK WORD': 719,
#  'LOVE BUILDING BLOCK WORD': 582,
#  'RECIPE BOX WITH METAL HEART': 5,
#  'DOORMAT NEW ENGLAND': 539,
#  'JAM MAKING SET WITH JARS': 974,
#  'RED COAT RACK PARIS FASHION': 97,
#  'YELLOW COAT RACK PARIS FASHION': 93,
#  'BLUE COAT RACK PARIS FASHION': 140,
#  'BATH BUILDING BLOCK WORD': 257,
#  'ALARM CLOCK BAKELIKE PINK': 638,
#  'ALARM CLOCK BAKELIKE RED ': 932,
#  'ALARM CLOCK BAKELIKE GREEN': 831,
#  'PANDA AND BUNNIES STICKER SHEET': 57,
#  'STARS GIFT TAPE ': 94,
#  'INFLATABLE POLITICAL GLOBE ': 49,
#  'VINTAGE HEADS AND TAILS CARD GAME ': 494,
#  'SET/2 RED RETROSPOT TEA TOWELS ': 227,
#  'ROUND SNACK BOXES SET OF4 WOODLAND ': 627,
#  'SPACEBOY LUNCH BOX ': 728,
#  'LUNCH BOX I LOVE LONDON': 547,
#  'CIRCUS PARADE LUNCH BOX ': 267,
#  'CHARLOTTE BAG DOLLY GIRL DESIGN': 353,
#  'RED TOADSTOOL LED NIGHT LIGHT': 546,
#  ' SET 2 TEA TOWELS I LOVE LONDON ': 205,
#  'VINTAGE SEASIDE JIGSAW PUZZLES': 91,
#  'MINI JIGSAW CIRCUS PARADE ': 66,
#  'MINI JIGSAW SPACEBOY': 129,
#  'MINI PAINT SET VINTAGE ': 335,
#  'POSTAGE': 1196,
#  "PAPER CHAIN KIT 50'S CHRISTMAS ": 1029,
#  'EDWARDIAN PARASOL RED': 274,
#  'RETRO COFFEE MUGS ASSORTED': 125,
#  'SAVE THE PLANET MUG': 286,
#  'VINTAGE BILLBOARD DRINK ME MUG': 111,
#  'VINTAGE BILLBOARD LOVE/HATE MUG': 129,
#  'WOOD 2 DRAWER CABINET WHITE FINISH': 566,
#  'WOOD S/3 CABINET ANT WHITE FINISH': 394,
#  'WOODEN PICTURE FRAME WHITE FINISH': 905,
#  'WOODEN FRAME ANTIQUE WHITE ': 836,
#  'VICTORIAN SEWING BOX LARGE': 124,
#  'HOT WATER BOTTLE TEA AND SYMPATHY': 524,
#  'RED HANGING HEART T-LIGHT HOLDER': 709,
#  'JUMBO BAG PINK POLKADOT': 903,
#  'JUMBO  BAG BAROQUE BLACK WHITE': 673,
#  'JUMBO BAG CHARLIE AND LOLA TOYS': 110,
#  'STRAWBERRY CHARLOTTE BAG': 512,
#  'RED 3 PIECE RETROSPOT CUTLERY SET': 100,
#  'BLUE 3 PIECE POLKADOT CUTLERY SET': 97,
#  'SET/6 RED SPOTTY PAPER PLATES': 328,
#  'LUNCH BAG RED RETROSPOT': 1358,
#  'STRAWBERRY LUNCH BOX WITH CUTLERY': 448,
#  'LUNCH BOX WITH CUTLERY RETROSPOT ': 340,
#  'PACK OF 72 RETROSPOT CAKE CASES': 1080,
#  'PACK OF 60 DINOSAUR CAKE CASES': 569,
#  'PACK OF 60 PINK PAISLEY CAKE CASES': 692,
#  '60 TEATIME FAIRY CAKE CASES': 698,
#  'TOMATO CHARLIE+LOLA COASTER SET': 61,
#  'CHARLIE & LOLA WASTEPAPER BIN FLORA': 107,
#  'RED CHARLIE+LOLA PERSONAL DOORSIGN': 111,
#  'JUMBO STORAGE BAG SUKI': 800,
#  'JUMBO BAG PINK VINTAGE PAISLEY': 618,
#  'JAM MAKING SET PRINTED': 888,
#  'RETROSPOT TEA SET CERAMIC 11 PC ': 849,
#  'GIRLY PINK TOOL SET': 1,
#  'JUMBO SHOPPER VINTAGE RED PAISLEY': 814,
#  'AIRLINE LOUNGE,METAL SIGN': 151,
#  'WHITE SPOT RED CERAMIC DRAWER KNOB': 322,
#  'RED DRAWER KNOB ACRYLIC EDWARDIAN': 103,
#  'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN': 338,
#  'PHOTO CLIP LINE': 35,
#  'FELT EGG COSY CHICKEN': 99,
#  'PIGGY BANK RETROSPOT ': 289,
#  'SKULL SHOULDER BAG': 144,
#  "YOU'RE CONFUSING ME METAL SIGN ": 361,
#  'COOK WITH WINE METAL SIGN ': 624,
#  'GIN + TONIC DIET METAL SIGN': 671,
#  'YELLOW BREAKFAST CUP AND SAUCER': 16,
#  'PINK BREAKFAST CUP AND SAUCER ': 9,
#  'PAPER CHAIN KIT RETROSPOT': 452,
#  'SMALL HEART FLOWERS HOOK ': 118,
#  'TEA TIME DES TEA COSY': 80,
#  'FELT EGG COSY WHITE RABBIT ': 80,
#  'ZINC WILLIE WINKIE  CANDLE STICK': 193,
#  'CERAMIC CHERRY CAKE MONEY BANK': 194,
#  'RETROSPOT LARGE MILK JUG': 332,
#  'SET OF 6 FUNKY BEAKERS': 52,
#  'EDWARDIAN PARASOL BLACK': 296,
#  'EDWARDIAN PARASOL NATURAL': 388,
#  'CERAMIC STRAWBERRY CAKE MONEY BANK': 293,
#  'BLUE OWL SOFT TOY': 103,
#  'BALLOON ART MAKE YOUR OWN FLOWERS': 74,
#  'GLASS CLOCHE SMALL': 130,
#  'GUMBALL MONOCHROME COAT RACK': 38,
#  'DOORMAT FANCY FONT HOME SWEET HOME': 401,
#  'Discount': 77,
#  'VINTAGE SNAKES & LADDERS': 271,
#  'CHOCOLATE CALCULATOR': 122,
#  'RECYCLING BAG RETROSPOT ': 419,
#  'TOY TIDY PINK POLKADOT': 302,
#  'ANTIQUE GLASS DRESSING TABLE POT': 206,
#  'IVORY GIANT GARDEN THERMOMETER': 192,
#  '3 TIER CAKE TIN GREEN AND CREAM': 149,
#  '3 TIER CAKE TIN RED AND CREAM': 150,
#  'SET 3 WICKER OVAL BASKETS W LIDS': 32,
#  'SET OF 3 COLOURED  FLYING DUCKS': 46,
#  'WOOD BLACK BOARD ANT WHITE FINISH': 617,
#  'COLOUR GLASS T-LIGHT HOLDER HANGING': 547,
#  'HANGING METAL HEART LANTERN': 297,
#  'HANGING MEDINA LANTERN SMALL': 20,
#  'NATURAL SLATE HEART CHALKBOARD ': 997,
#  'HEART OF WICKER SMALL': 996,
#  'HEART OF WICKER LARGE': 835,
#  'WHITE LOVEBIRD LANTERN': 119,
#  'CLASSIC METAL BIRDCAGE PLANT HOLDER': 270,
#  'CREAM HEART CARD HOLDER': 464,
#  'ENAMEL FLOWER JUG CREAM': 459,
#  'ENAMEL FIRE BUCKET CREAM': 94,
#  'ENAMEL BREAD BIN CREAM': 345,
#  'JUMBO BAG DOLLY GIRL DESIGN': 320,
#  'TRADITIONAL CHRISTMAS RIBBONS': 275,
#  'ORGANISER WOOD ANTIQUE WHITE ': 85,
#  'LUNCH BAG DOLLY GIRL DESIGN': 621,
#  'WHITE WIRE EGG HOLDER': 70,
#  'JUMBO BAG RED RETROSPOT': 1662,
#  'CHILLI LIGHTS': 530,
#  'LIGHT GARLAND BUTTERFILES PINK': 140,
#  'WOODEN OWLS LIGHT GARLAND ': 158,
#  'FAIRY TALE COTTAGE NIGHTLIGHT': 70,
#  'HOME SMALL WOOD LETTERS': 101,
#  'GINGHAM HEART  DOORSTOP RED': 191,
#  'FIVE HEART HANGING DECORATION': 92,
#  'ASSORTED BOTTLE TOP  MAGNETS ': 137,
#  'FRIDGE MAGNETS US DINER ASSORTED': 92,
#  'HOMEMADE JAM SCENTED CANDLES': 527,
#  'FRIDGE MAGNETS LES ENFANTS ASSORTED': 82,
#  'ROSE CARAVAN DOORSTOP': 133,
#  '5 HOOK HANGER MAGIC TOADSTOOL': 30,
#  'CHRISTMAS LIGHTS 10 REINDEER': 275,
#  'VINTAGE UNION JACK CUSHION COVER': 100,
#  'SET OF 3 GOLD FLYING DUCKS': 21,
#  'RED RETROSPOT UMBRELLA': 308,
#  'BLACK/BLUE POLKADOT UMBRELLA': 258,
#  'RED DINER WALL CLOCK': 428,
#  'BLUE DINER WALL CLOCK': 345,
#  'IVORY DINER WALL CLOCK': 417,
#  'LARGE HEART MEASURING SPOONS': 229,
#  'SMALL HEART MEASURING SPOONS': 263,
#  'JAM JAR WITH PINK LID': 269,
#  'JAM JAR WITH GREEN LID': 222,
#  'ROSE COTTAGE KEEPSAKE BOX ': 155,
#  'HANGING HEART ZINC T-LIGHT HOLDER': 421,
#  'PAPER CHAIN KIT VINTAGE CHRISTMAS': 725,
#  'DISCO BALL CHRISTMAS DECORATION': 188,
#  'SMALL POPCORN HOLDER': 425,
#  'LARGE POPCORN HOLDER ': 68,
#  'SET/20 RED RETROSPOT PAPER NAPKINS ': 755,
#  'SET/6 RED SPOTTY PAPER CUPS': 296,
#  'POLKADOT RAIN HAT ': 98,
#  'DELUXE SEWING KIT ': 238,
#  'RETROSPOT HEART HOT WATER BOTTLE': 556,
#  'ENGLISH ROSE HOT WATER BOTTLE': 289,
#  'PHOTO CUBE': 178,
#  'PLASTERS IN TIN CIRCUS PARADE ': 541,
#  'PACK OF 12 PINK PAISLEY TISSUES ': 163,
#  'PACK OF 12 BLUE PAISLEY TISSUES ': 125,
#  'PACK OF 12 RED RETROSPOT TISSUES ': 254,
#  'CHICK GREY HOT WATER BOTTLE': 299,
#  'PLASTERS IN TIN VINTAGE PAISLEY ': 502,
#  'PLASTERS IN TIN SKULLS': 472,
#  '3 STRIPEY MICE FELTCRAFT': 417,
#  'SET OF 6 SOLDIER SKITTLES': 348,
#  'TRADITIONAL WOODEN SKIPPING ROPE': 363,
#  'WOODEN BOX OF DOMINOES': 468,
#  'RUSTIC  SEVENTEEN DRAWER SIDEBOARD': 29,
#  'PARTY CONES CARNIVAL ASSORTED': 21,
#  'PARTY CONES CANDY ASSORTED': 75,
#  'PICNIC BASKET WICKER SMALL': 246,
#  'STAR DECORATION PAINTED ZINC ': 123,
#  'RETROSPOT LAMP': 144,
#  'FANCY FONT BIRTHDAY CARD, ': 254,
#  'HAND WARMER SCOTTY DOG DESIGN': 506,
#  'HAND WARMER OWL DESIGN': 605,
#  'HAND WARMER RED RETROSPOT': 361,
#  'DOG BOWL CHASING BALL DESIGN': 118,
#  'CLOTHES PEGS RETROSPOT PACK 24 ': 659,
#  'HAND OVER THE CHOCOLATE   SIGN ': 599,
#  'TRAVEL SEWING KIT': 404,
#  'BLACK HEART CARD HOLDER': 168,
#  'SMALL GLASS HEART TRINKET POT': 386,
#  'ALARM CLOCK BAKELIKE IVORY': 491,
#  'ALARM CLOCK BAKELIKE ORANGE': 385,
#  'HAND WARMER BIRD DESIGN': 494,
#  'IVORY EMBROIDERED QUILT ': 25,
#  'SET OF 3 BLACK FLYING DUCKS': 57,
#  'RED RETROSPOT MUG': 147,
#  'BABUSHKA LIGHTS STRING OF 10': 118,
#  'DOORMAT FAIRY CAKE': 247,
#  'STRAWBERRY CERAMIC TRINKET BOX': 570,
#  'PINK DOUGHNUT TRINKET POT ': 188,
#  'SILK PURSE BABUSHKA PINK': 90,
#  'HOT WATER BOTTLE I AM SO POORLY': 523,
#  'CHOCOLATE HOT WATER BOTTLE': 721,
#  'WHITE SKULL HOT WATER BOTTLE ': 395,
#  'SCOTTIE DOG HOT WATER BOTTLE': 678,
#  'BIRD HOUSE HOT WATER BOTTLE': 164,
#  'BOUDOIR SQUARE TISSUE BOX': 157,
#  'SKULLS SQUARE TISSUE BOX': 40,
#  'PHOTO FRAME CORNICE': 481,
#  'SILK PURSE BABUSHKA RED': 39,
#  'PICTURE DOMINOES': 250,
#  'S/6 SEW ON CROCHET FLOWERS': 18,
#  'SCANDINAVIAN REDS RIBBONS': 349,
#  'BALLOONS  WRITING SET ': 194,
#  'LAVENDER INCENSE IN TIN': 26,
#  'TV DINNER TRAY VINTAGE PAISLEY': 79,
#  'SET OF 4 ENGLISH ROSE PLACEMATS': 142,
#  'SET OF 4 ENGLISH ROSE COASTERS': 152,
#  'TRIPLE PHOTO FRAME CORNICE ': 225,
#  'FAMILY PHOTO FRAME CORNICE': 260,
#  'MIRRORED DISCO BALL ': 139,
#  'DISCO BALL ROTATOR BATTERY OPERATED': 106,
#  'SILVER LOOKING MIRROR': 2,
#  'LADIES & GENTLEMEN METAL SIGN': 373,
#  'METAL SIGN HER DINNER IS SERVED ': 72,
#  'DOORMAT TOPIARY': 187,
#  'BATHROOM METAL SIGN': 393,
#  'KITCHEN METAL SIGN': 225,
#  'TOILET METAL SIGN': 308,
#  'METAL SIGN TAKE IT OR LEAVE IT ': 361,
#  "I'M ON HOLIDAY METAL SIGN": 334,
#  'GROW YOUR OWN BASIL IN ENAMEL MUG': 176,
#  'SET/10 PINK POLKADOT PARTY CANDLES': 318,
#  'SET 20 NAPKINS FAIRY CAKES DESIGN ': 299,
#  'SET OF 6 T-LIGHTS SNOWMEN': 143,
#  'SET OF 6 T-LIGHTS SANTA': 181,
#  'SET OF 9 HEART SHAPED BALLOONS': 222,
#  'SANDWICH BATH SPONGE': 41,
#  'APPLE BATH SPONGE': 126,
#  'STRAWBERRY BATH SPONGE ': 131,
#  'BLACK PIRATE TREASURE CHEST': 87,
#  'STAR PORTABLE TABLE LIGHT ': 34,
#  'SNOWFLAKE PORTABLE TABLE LIGHT ': 84,
#  'PINK OVAL JEWELLED MIRROR': 11,
#  'RETROSPOT CIGAR BOX MATCHES ': 225,
#  'COSY HOUR GIANT TUBE MATCHES': 30,
#  'JAZZ HEARTS PURSE NOTEBOOK': 261,
#  'CANDLEHOLDER PINK HANGING HEART': 360,
#  'ASSORTED COLOUR MINI CASES': 374,
#  'LUNCH BAG SPACEBOY DESIGN ': 1021,
#  'LUNCH BAG WOODLAND': 861,
#  'LUNCH BAG PINK POLKADOT': 977,
#  'GUMBALL COAT RACK': 615,
#  'BLUE NEW BAROQUE CANDLESTICK CANDLE': 33,
#  'PINK NEW BAROQUECANDLESTICK CANDLE': 33,
#  'FAIRY CAKE FLANNEL ASSORTED COLOUR': 200,
#  'BREAD BIN DINER STYLE PINK': 120,
#  'TEA TIME TABLE CLOTH': 26,
#  'HOT WATER BOTTLE BABUSHKA ': 137,
#  'HEART IVORY TRELLIS SMALL': 232,
#  'PINK DRAWER KNOB ACRYLIC EDWARDIAN': 179,
#  'GREEN DRAWER KNOB ACRYLIC EDWARDIAN': 150,
#  'BLUE DRAWER KNOB ACRYLIC EDWARDIAN': 127,
#  'SET 6 FOOTBALL CELEBRATION CANDLES': 73,
#  'SET OF 6 GIRLS CELEBRATION CANDLES': 69,
#  'ROMANTIC PINKS RIBBONS ': 212,
#  'BRIGHT BLUES RIBBONS ': 106,
#  'CHOCOLATE BOX RIBBONS ': 246,
#  'PARTY INVITES FOOTBALL': 52,
#  'PARTY INVITES JAZZ HEARTS': 81,
#  'PARTY INVITES SPACEMAN': 62,
#  'SET OF 3 BUTTERFLY COOKIE CUTTERS': 515,
#  'SET OF 3 HEART COOKIE CUTTERS': 536,
#  '3 PIECE SPACEBOY COOKIE CUTTER SET': 309,
#  'PACK OF 72 SKULL CAKE CASES': 512,
#  'PACK OF 60 SPACEBOY CAKE CASES': 422,
#  '72 SWEETHEART FAIRY CAKE CASES': 535,
#  'LUNCH BAG SUKI  DESIGN ': 153,
#  'LUNCH BAG CARS BLUE': 1012,
#  'LUNCH BAG  BLACK SKULL.': 1126,
#  'HEART IVORY TRELLIS LARGE': 285,
#  'SET/5 RED RETROSPOT LID GLASS BOWLS': 817,
#  'MAGIC DRAWING SLATE DINOSAUR': 139,
#  'MAGIC DRAWING SLATE BAKE A CAKE ': 80,
#  '12 PENCILS TALL TUBE SKULLS': 225,
#  'RED  HARMONICA IN BOX ': 575,
#  'BLUE HARMONICA IN BOX ': 529,
#  'SKULLS  WATER TRANSFER TATTOOS ': 115,
#  'PACK 3 BOXES BIRD PANNETONE ': 140,
#  'SET OF 20 KIDS COOKIE CUTTERS': 430,
#  '10 COLOUR SPACEBOY PEN': 250,
#  'VICTORIAN GLASS HANGING T-LIGHT': 849,
#  'SINGLE HEART ZINC T-LIGHT HOLDER': 339,
#  'HANGING METAL STAR LANTERN': 170,
#  'SILVER HANGING T-LIGHT HOLDER': 289,
#  'DOORMAT RED RETROSPOT': 586,
#  'DOORMAT HEARTS': 486,
#  'NATURAL SLATE RECTANGLE CHALKBOARD': 321,
#  'LOVEBIRD HANGING DECORATION WHITE ': 327,
#  'PENS ASSORTED FUNNY FACE': 173,
#  'CARD CIRCUS PARADE': 215,
#  'WRAP COWBOYS  ': 70,
#  'AIRLINE BAG VINTAGE TOKYO 78': 263,
#  'SET OF 72 RETROSPOT PAPER  DOILIES': 373,
#  'SLEEPING CAT ERASERS': 170,
#  'CARD BIRTHDAY COWBOY': 156,
#  'PACK 3 BOXES CHRISTMAS PANNETONE': 117,
#  'ROTATING SILVER ANGELS T-LIGHT HLDR': 330,
#  'RIBBON REEL MAKING SNOWMEN ': 157,
#  '4 TRADITIONAL SPINNING TOPS': 377,
#  'BAG 500g SWIRLY MARBLES': 115,
#  '5 STRAND GLASS NECKLACE CRYSTAL': 12,
#  'SQUARECUSHION COVER PINK UNION FLAG': 25,
#  'SPACEBOY CHILDRENS EGG CUP': 145,
#  "CHILDREN'S SPACEBOY MUG": 190,
#  'FELTCRAFT CUSHION OWL': 434,
#  'BLACK CANDELABRA T-LIGHT HOLDER': 40,
#  'TOY TIDY DOLLY GIRL DESIGN': 105,
#  'SET 12 LAVENDER  BOTANICAL T-LIGHTS': 75,
#  'UNION JACK FLAG LUGGAGE TAG': 110,
#  'RED HEART LUGGAGE TAG': 47,
#  'RED GLASS TASSLE BAG CHARM': 5,
#  'CLEAR ACRYLIC FACETED BANGLE': 6,
#  'DOORMAT UNION JACK GUNS AND ROSES': 158,
#  'VANILLA SCENT CANDLE JEWELLED BOX': 95,
#  'FULL ENGLISH BREAKFAST PLATE': 168,
#  'MAGIC DRAWING SLATE CIRCUS PARADE  ': 166,
#  'CHRISTMAS HANGING HEART WITH BELL': 20,
#  'CAKE STAND VICTORIAN FILIGREE MED': 19,
#  'PAISLEY PATTERN  STICKERS': 16,
#  'FLOWERS  STICKERS': 32,
#  'BLACK LOVE BIRD CANDLE': 25,
#  'PARTY TIME PENCIL ERASERS': 80,
#  "PINK B'FLY C/COVER W BOBBLES": 6,
#  'PINK UNION JACK  LUGGAGE TAG': 88,
#  '6 RIBBONS ELEGANT CHRISTMAS ': 126,
#  'AGED GLASS SILVER T-LIGHT HOLDER': 292,
#  'BOOM BOX SPEAKER GIRLS': 44,
#  '6 RIBBONS SHIMMERING PINKS ': 78,
#  'JUMBO BAG OWLS': 427,
#  'OWL DOORSTOP': 118,
#  'PAINTED METAL STAR WITH HOLLY BELLS': 78,
#  'PAINTED METAL HEART WITH HOLLY BELL': 77,
#  'ANGEL DECORATION STARS ON DRESS': 96,
#  'JUMBO BAG STRAWBERRY': 677,
#  'STRAWBERRY SHOPPER BAG': 237,
#  'ROUND SNACK BOXES SET OF 4 FRUITS ': 486,
#  'ROUND SNACK BOXES SET OF 4 SKULLS': 178,
#  'DOLLY GIRL LUNCH BOX': 645,
#  'GREEN POLKADOT PLATE ': 103,
#  'BLUE POLKADOT PLATE ': 151,
#  'RED RETROSPOT PLATE ': 229,
#  'PINK  POLKADOT PLATE ': 132,
#  'FELTCRAFT DOLL MOLLY': 306,
#  'FELTCRAFT CHRISTMAS FAIRY': 319,
#  'SET OF 3 NOTEBOOKS IN PARCEL': 338,
#  'RED RETROSPOT TAPE': 101,
#  'COSY SLIPPER SHOES SMALL  RED ': 22,
#  '6 RIBBONS RUSTIC CHARM': 757,
#  '12 DAISY PEGS IN WOOD BOX': 69,
#  '5 HOOK HANGER RED MAGIC TOADSTOOL': 114,
#  'CHRISTMAS CRAFT TREE TOP ANGEL': 363,
#  'CHRISTMAS CRAFT LITTLE FRIENDS': 440,
#  'COSY SLIPPER SHOES SMALL GREEN': 50,
#  'FELTCRAFT DOLL ROSIE': 265,
#  'FELTCRAFT DOLL EMILY': 240,
#  'FELTCRAFT PRINCESS OLIVIA DOLL': 256,
#  'REX CASH+CARRY JUMBO SHOPPER': 955,
#  'FELTCRAFT CUSHION RABBIT': 336,
#  'FELTCRAFT CUSHION BUTTERFLY': 304,
#  'TOTE BAG I LOVE LONDON': 98,
#  'FOLDING UMBRELLA PINKWHITE POLKADOT': 31,
#  'FOLDING UMBRELLA CREAM POLKADOT': 34,
#  'FOLDING UMBRELLA WHITE/RED POLKADOT': 23,
#  'SET 10 LIGHTS NIGHT OWL': 83,
#  'FOLDING UMBRELLA RED/WHITE POLKADOT': 69,
#  'S/4 VALENTINE DECOUPAGE HEART BOX': 93,
#  'SOLDIERS EGG CUP ': 347,
#  'RED RETROSPOT MINI CASES': 371,
#  '60 CAKE CASES VINTAGE CHRISTMAS': 499,
#  'RIBBON REEL CHRISTMAS SOCK BAUBLE': 213,
#  'RIBBON REEL SNOWY VILLAGE': 183,
#  'SET OF 20 VINTAGE CHRISTMAS NAPKINS': 518,
#  'TURQUOISE CHRISTMAS TREE ': 4,
#  'RED STAR CARD HOLDER': 123,
#  'WICKER WREATH SMALL': 98,
#  'ADVENT CALENDAR GINGHAM SACK': 172,
#  'FELTCRAFT BUTTERFLY HEARTS': 461,
#  'PARTY CONE CHRISTMAS DECORATION ': 93,
#  'WICKER STAR ': 316,
#  'VINTAGE SNAP CARDS': 740,
#  'FELTCRAFT 6 FLOWER FRIENDS': 482,
#  'BIRD DECORATION RED RETROSPOT': 59,
#  'CHRISTMAS GINGHAM TREE': 127,
#  'CHRISTMAS GINGHAM STAR': 143,
#  'CHRISTMAS GINGHAM HEART': 31,
#  'PACK OF 12 PINK POLKADOT TISSUES': 157,
#  'FELTCRAFT PRINCESS LOLA DOLL': 393,
#  'PACK OF 12 LONDON TISSUES ': 399,
#  'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN': 163,
#  "CHILDREN'S APRON DOLLY GIRL ": 266,
#  'CHILDRENS APRON SPACEBOY DESIGN': 469,
#  'CHRISTMAS LIGHTS 10 SANTAS ': 144,
#  'PACK OF 60 MUSHROOM CAKE CASES': 291,
#  '60 CAKE CASES DOLLY GIRL DESIGN': 374,
#  'HAND WARMER BABUSHKA DESIGN': 306,
#  'SET 12 RETRO WHITE CHALK STICKS': 256,
#  'FELTCRAFT HAIRBAND RED AND BLUE': 124,
#  'FELTCRAFT HAIRBAND PINK AND PURPLE': 124,
#  'FELTCRAFT HAIRBANDS PINK AND WHITE ': 110,
#  'TV DINNER TRAY DOLLY GIRL': 84,
#  'PLASTERS IN TIN SPACEBOY': 602,
#  'PLASTERS IN TIN WOODLAND ANIMALS': 610,
#  'MAGIC DRAWING SLATE SPACEBOY ': 208,
#  'MAGIC DRAWING SLATE GO TO THE FAIR ': 62,
#  'MAGIC DRAWING SLATE DOLLY GIRL ': 187,
#  'CHARLIE + LOLA RED HOT WATER BOTTLE': 137,
#  'URBAN BLACK RIBBONS ': 77,
#  'SET OF 6 T-LIGHTS TOADSTOOLS': 111,
#  'ROTATING LEAVES T-LIGHT HOLDER': 135,
#  'CUPCAKE LACE PAPER SET 6': 176,
#  'TRADITIONAL WOODEN CATCH CUP GAME ': 307,
#  'S/6 WOODEN SKITTLES IN COTTON BAG': 184,
#  'RED METAL BEACH SPADE ': 146,
#  'BOYS VINTAGE TIN SEASIDE BUCKET': 140,
#  'GIRLS VINTAGE TIN SEASIDE BUCKET': 139,
#  'GREY HEART HOT WATER BOTTLE': 544,
#  'KINGS CHOICE TEA CADDY ': 117,
#  'KINGS CHOICE BISCUIT TIN': 95,
#  'METAL SIGN EMPIRE TEA': 185,
#  'FAWN BLUE HOT WATER BOTTLE': 394,
#  'PACK OF 6 BIRDY GIFT TAGS': 343,
#  'CERAMIC STRAWBERRY MONEY BOX': 48,
#  'CERAMIC HEART FAIRY CAKE MONEY BANK': 241,
#  'CERAMIC PIRATE CHEST MONEY BANK': 110,
#  'DOORSTOP RETROSPOT HEART': 244,
#  'RETROSPOT BABUSHKA DOORSTOP': 48,
#  'SWEETHEART WIRE WALL TIDY': 101,
#  'RED RETROSPOT OVEN GLOVE ': 272,
#  'NAMASTE SWAGAT INCENSE': 57,
#  'CERAMIC STRAWBERRY DESIGN MUG': 161,
#  'CLASSICAL ROSE SMALL VASE': 12,
#  'HYACINTH BULB T-LIGHT CANDLES': 45,
#  'CHRISTMAS CRAFT WHITE FAIRY ': 335,
#  'COSY HOUR CIGAR BOX MATCHES ': 156,
#  'RED TEA TOWEL CLASSIC DESIGN': 68,
#  'HEART FILIGREE DOVE  SMALL': 264,
#  'RETROSPOT CHILDRENS APRON': 302,
#  'COLOURING PENCILS BROWN TUBE': 247,
#  '4 IVORY DINNER CANDLES SILVER FLOCK': 102,
#  'ZINC METAL HEART DECORATION': 493,
#  'GREEN FERN NOTEBOOK': 23,
#  'BLUE PAISLEY NOTEBOOK': 24,
#  'CHRYSANTHEMUM NOTEBOOK': 36,
#  'LARGE CHINESE STYLE SCISSOR': 65,
#  'SMALL CHINESE STYLE SCISSOR': 54,
#  'HANGING GLASS ETCHED TEALIGHT': 11,
#  'COOKING SET RETROSPOT': 28,
#  'KINGS CHOICE GIANT TUBE MATCHES': 68,
#  'PLACE SETTING WHITE STAR': 100,
#  'S/15 SILVER GLASS BAUBLES IN BAG': 38,
#  'FRENCH WC SIGN BLUE METAL': 213,
#  'FAIRY SOAP SOAP HOLDER': 58,
#  'GREEN GIANT GARDEN THERMOMETER': 136,
#  'BLUE GIANT GARDEN THERMOMETER': 169,
#  'VICTORIAN SEWING BOX SMALL ': 246,
#  'VICTORIAN SEWING BOX MEDIUM': 159,
#  'SET/10 RED POLKADOT PARTY CANDLES': 346,
#  'WASHROOM METAL SIGN': 299,
#  'BLACK SWEETHEART BRACELET': 25,
#  'DIAMANTE HAIR GRIP PACK/2 BLACK DIA': 4,
#  'BLACK DIAMANTE EXPANDABLE RING': 8,
#  'DIAMANTE HAIR GRIP PACK/2 RUBY': 4,
#  'DIAMANTE HAIR GRIP PACK/2 MONTANA': 4,
#  'BLUE SWEETHEART BRACELET': 7,
#  'PINK SWEETHEART BRACELET': 25,
#  'PURPLE SWEETHEART BRACELET': 16,
#  'RIBBON REEL CHRISTMAS PRESENT ': 192,
#  'FIRST AID TIN': 152,
#  'MAKE YOUR OWN MONSOON CARD KIT': 152,
#  'PACK OF 12 HEARTS DESIGN TISSUES ': 361,
#  'HEART FILIGREE DOVE LARGE': 222,
#  'SWIRLY CIRCULAR RUBBERS IN BAG': 39,
#  'VINTAGE PAISLEY STATIONERY SET': 216,
#  'SET/10 BLUE POLKADOT PARTY CANDLES': 235,
#  'RIBBON REEL SOCKS AND MITTENS': 89,
#  'CHRISTMAS METAL TAGS ASSORTED ': 144,
#  'CHRISTMAS TREE T-LIGHT HOLDER': 9,
#  'STAR  T-LIGHT HOLDER ': 20,
#  'HEART T-LIGHT HOLDER ': 15,
#  'MINI FUNKY DESIGN TAPES': 64,
#  'STAR WOODEN CHRISTMAS DECORATION': 156,
#  'WOODEN HEART CHRISTMAS SCANDINAVIAN': 482,
#  'CHRISTMAS RETROSPOT TREE WOOD': 133,
#  'SET/9 CHRISTMAS T-LIGHTS SCENTED ': 8,
#  'BLUE ROSE FABRIC MIRROR': 39,
#  'THREE CANVAS LUGGAGE TAGS': 10,
#  'RETROSPOT PARTY BAG + STICKER SET': 283,
#  'RETROSPOT SMALL TUBE MATCHES': 160,
#  '3D CHRISTMAS STAMPS STICKERS ': 107,
#  '36 FOIL HEART CAKE CASES': 181,
#  'PACK OF 6 SWEETIE GIFT BOXES': 80,
#  'CINAMMON SET OF 9 T-LIGHTS': 112,
#  'ORANGE SCENTED SET/9 T-LIGHTS': 68,
#  'RIBBON REEL STRIPES DESIGN ': 354,
#  'SET OF 2 TINS JARDIN DE PROVENCE': 90,
#  'MAKE YOUR OWN PLAYTIME CARD KIT': 92,
#  'DINOSAURS  WRITING SET ': 172,
#  'SKULLS WRITING SET ': 148,
#  'DOORMAT BLACK FLOCK ': 178,
#  'CHRISTMAS DECOUPAGE CANDLE': 66,
#  'OFFICE MUG WARMER POLKADOT': 99,
#  'BLACK RECORD COVER FRAME': 322,
#  'RECORD FRAME 7" SINGLE SIZE ': 203,
#  '36 PENCILS TUBE RED RETROSPOT': 250,
#  '36 PENCILS TUBE WOODLAND': 149,
#  'ROCKING HORSE RED CHRISTMAS ': 188,
#  'REGENCY CAKESTAND 3 TIER': 1905,
#  'VINTAGE UNION JACK BUNTING': 406,
#  'RETRO LONGBOARD IRONING BOARD COVER': 47,
#  '3D DOG PICTURE PLAYING CARDS': 64,
#  'SAVE THE PLANET COTTON TOTE BAG': 118,
#  'PAPER BUNTING WHITE LACE': 273,
#  'GENTLEMAN SHIRT REPAIR KIT ': 94,
#  'CARD I LOVE LONDON ': 156,
#  'MIRRORED WALL ART FOXY': 8,
#  'MIRRORED WALL ART GENTS': 35,
#  'AIRLINE BAG VINTAGE JET SET WHITE': 85,
#  "POTTING SHED SOW 'N' GROW SET": 1,
#  'AIRLINE BAG VINTAGE WORLD CHAMPION ': 102,
#  'PINK HEARTS PAPER GARLAND': 8,
#  'POTTING SHED SEED ENVELOPES': 75,
#  'HI TEC ALPINE HAND WARMER': 59,
#  'POLYESTER FILLER PAD 45x45cm': 135,
#  'CARD DOLLY GIRL ': 219,
#  'CARD BILLBOARD FONT': 335,
#  'RAINY LADIES BIRTHDAY CARD': 132,
#  'RED WHITE SCARF  HOT WATER BOTTLE': 2,
#  'SET OF 2 TEA TOWELS APPLE AND PEARS': 246,
#  'LANTERN CREAM GAZEBO ': 296,
#  'BLUE BIRDHOUSE DECORATION': 38,
#  'ANTIQUE SILVER TEA GLASS ENGRAVED': 302,
#  'SET OF 2 WOODEN MARKET CRATES': 169,
#  'CLASSIC FRENCH STYLE BASKET NATURAL': 95,
#  'CRAZY DAISY HEART DECORATION': 32,
#  'CARD HOLDER GINGHAM HEART': 140,
#  'SMALL STRIPES CHOCOLATE GIFT BAG ': 26,
#  'TRAY, BREAKFAST IN BED': 72,
#  'PIZZA PLATE IN BOX': 78,
#  'PINK HEART DOTS HOT WATER BOTTLE': 4,
#  'PLACE SETTING WHITE HEART': 302,
#  'SET OF 4 NAPKIN CHARMS LEAVES   ': 32,
#  'SET OF 4 NAPKIN CHARMS STARS   ': 45,
#  'SET OF 4 NAPKIN CHARMS CUTLERY': 114,
#  'CARAVAN SQUARE TISSUE BOX': 134,
#  'BUTTON BOX ': 124,
#  '12 MESSAGE CARDS WITH ENVELOPES': 200,
#  'SMALL RED BABUSHKA NOTEBOOK ': 196,
#  'HERB MARKER MINT': 199,
#  'HERB MARKER ROSEMARY': 199,
#  'HERB MARKER BASIL': 196,
#  'HERB MARKER CHIVES ': 173,
#  'HERB MARKER PARSLEY': 196,
#  'HERB MARKER THYME': 195,
#  'METAL MERRY CHRISTMAS WREATH': 80,
#  'WHITE CHRISTMAS GARLAND STARS TREES': 41,
#  'RETROSPOT GIANT TUBE MATCHES': 139,
#  '36 FOIL STAR CAKE CASES ': 112,
#  'PACK OF 6 HANDBAG GIFT BOXES': 81,
#  'GARLAND WOODEN HAPPY EASTER': 173,
#  'CALENDAR PAPER CUT DESIGN': 242,
#  'CALENDAR IN SEASON DESIGN': 69,
#  'BLUE PAISLEY TISSUE BOX': 90,
#  'PINK PAISLEY SQUARE TISSUE BOX ': 119,
#  'TOAST ITS - HAPPY BIRTHDAY': 60,
#  'SET/10 IVORY POLKADOT PARTY CANDLES': 103,
#  'SKULLS STORAGE BOX SMALL': 28,
#  'JUMBO STORAGE BAG SKULLS': 484,
#  'GARDEN PATH JOURNAL': 47,
#  'BLACK ORANGE SQUEEZER': 21,
#  'SET OF 72 GREEN PAPER DOILIES': 21,
#  'RETROSPOT RED WASHING UP GLOVES': 244,
#  'SMALL LICORICE DES PINK BOWL': 36,
#  'SWISS ROLL TOWEL, CHOCOLATE  SPOTS': 52,
#  'PICNIC BASKET WICKER LARGE': 276,
#  'CREAM SWEETHEART EGG HOLDER': 152,
#  'PINK 3 PIECE POLKADOT CUTLERY SET': 103,
#  'PINK PARTY BAGS': 147,
#  'BLUE PARTY BAGS ': 110,
#  'PINK CREAM FELT CRAFT TRINKET BOX ': 552,
#  'RED RETROSPOT OVEN GLOVE DOUBLE': 149,
#  'RIDGED GLASS STORAGE JAR CREAM LID': 19,
#  'PACK OF 20 NAPKINS PANTRY DESIGN': 570,
#  'SWEETHEART CAKESTAND 3 TIER': 356,
#  'CHRISTMAS HANGING STAR WITH BELL': 191,
#  'MULTICOLOUR  CONFETTI IN TUBE': 14,
#  'CHOCOLATE 3 WICK MORRIS BOX CANDLE': 44,
#  'SET OF 16 VINTAGE PISTACHIO CUTLERY': 50,
#  'CHRISTMAS TOILET ROLL': 186,
#  'WHITE BELL HONEYCOMB PAPER ': 43,
#  ' 4 PURPLE FLOCK DINNER CANDLES': 39,
#  'PINK & WHITE BREAKFAST TRAY': 14,
#  'ENGLISH ROSE SPIRIT LEVEL ': 93,
#  'LARGE ROUND WICKER PLATTER ': 92,
#  'BLACK TEA TOWEL CLASSIC DESIGN': 87,
#  'CHRISTMAS LIGHTS 10 VINTAGE BAUBLES': 171,
#  'ROSES REGENCY TEACUP AND SAUCER ': 854,
#  'T-LIGHT HOLDER HANGING LACE': 66,
#  'HANGING HEART MIRROR DECORATION ': 184,
#  'CREAM SLICE FLANNEL CHOCOLATE SPOT ': 35,
#  'CREAM SLICE FLANNEL PINK SPOT ': 66,
#  'GREEN REGENCY TEACUP AND SAUCER': 761,
#  'EIGHT PIECE DINOSAUR SET': 21,
#  'HEADS AND TAILS SPORTING FUN': 184,
#  "ASS COL SMALL SAND GECKO P'WEIGHT": 10,
#  'ENAMEL MEASURING JUG CREAM': 340,
#  '12 PENCILS SMALL TUBE SKULL': 306,
#  '12 PENCIL SMALL TUBE WOODLAND': 293,
#  'BLUE PAPER PARASOL ': 49,
#  'VICTORIAN  METAL POSTCARD SPRING': 170,
#  'METAL 4 HOOK HANGER FRENCH CHATEAU': 348,
#  'BLACK KITCHEN SCALES': 190,
#  'RED KITCHEN SCALES': 474,
#  'IVORY KITCHEN SCALES': 645,
#  'MULTI COLOUR SILVER T-LIGHT HOLDER': 330,
#  '3 HOOK HANGER MAGIC GARDEN': 105,
#  'ASSORTED COLOUR LIZARD SUCTION HOOK': 63,
#  'JUMBO BAG WOODLAND ANIMALS': 506,
#  "CHILDREN'S CIRCUS PARADE MUG": 117,
#  'PACK 3 FIRE ENGINE/CAR PATCHES': 12,
#  'CARD PSYCHEDELIC APPLES': 114,
#  'IVORY ENCHANTED FOREST PLACEMAT': 53,
#  'PACK OF 6 PANNETONE GIFT BOXES': 143,
#  'MEASURING TAPE BABUSHKA RED': 38,
#  'RED ENCHANTED FOREST PLACEMAT': 63,
#  'CHILDRENS DOLLY GIRL MUG': 169,
#  'TOADSTOOL MONEY BOX': 148,
#  'MAKE YOUR OWN FLOWERPOWER CARD KIT': 153,
#  'PAPER CHAIN KIT LONDON': 84,
#  'MEASURING TAPE BABUSHKA BLUE': 47,
#  'PENCIL CASE LIFE IS BEAUTIFUL': 100,
#  'WOODEN ROUNDERS GARDEN SET ': 311,
#  'CHILDS BREAKFAST SET DOLLY GIRL ': 190,
#  'CHILDS BREAKFAST SET SPACEBOY ': 231,
#  'CAKE PLATE LOVEBIRD WHITE': 149,
#  'WOODEN ADVENT CALENDAR RED': 107,
#  'GREEN CHRISTMAS TREE CARD HOLDER': 150,
#  'STRING OF STARS CARD HOLDER': 12,
#  'SET/12 TAPER CANDLES': 43,
#  'MINT KITCHEN SCALES': 320,
#  'WHITE WOOD GARDEN PLANT LADDER': 397,
#  'GLASS JAR ENGLISH CONFECTIONERY': 167,
#  'GLASS JAR DIGESTIVE BISCUITS': 113,
#  'MILK BOTTLE WITH GLASS STOPPER ': 15,
#  'WELCOME  WOODEN BLOCK LETTERS': 172,
#  'SET/4 MODERN VINTAGE COTTON NAPKINS': 24,
#  'VINTAGE UNION JACK APRON': 118,
#  'SWALLOW SQUARE TISSUE BOX': 153,
#  'NO JUNK MAIL METAL SIGN': 175,
#  'SLATE TILE NATURAL HANGING': 130,
#  'VINTAGE GLASS COFFEE CADDY': 16,
#  'SILVER GLASS T-LIGHT SET': 15,
#  'RIDGED GLASS FINGER BOWL': 50,
#  'GLASS  BEURRE DISH': 153,
#  'GIN & TONIC DIET GREETING CARD ': 194,
#  'BIRTHDAY CARD, RETRO SPOT': 126,
#  'WRAP RED APPLES ': 176,
#  'RED RETROSPOT WRAP ': 338,
#  'WRAP CHRISTMAS SCREEN PRINT': 33,
#  'FANCY FONTS BIRTHDAY WRAP': 232,
#  'CLASSIC WHITE FRAME': 15,
#  'BLACK DINER WALL CLOCK': 34,
#  'DOORMAT PEACE ON EARTH BLUE': 27,
#  'BOX OF 24 COCKTAIL PARASOLS': 377,
#  'GROW YOUR OWN PLANT IN A CAN ': 37,
#  'PLASTERS IN TIN STRONGMAN': 465,
#  'MINI JIGSAW DINOSAUR ': 52,
#  'MINI JIGSAW BAKE A CAKE ': 41,
#  'MINI JIGSAW DOLLY GIRL': 90,
#  'WOODEN SCHOOL COLOURING SET': 411,
#  'PACK OF 12 TRADITIONAL CRAYONS': 324,
#  'CARD PARTY GAMES ': 96,
#  'BOOZE & WOMEN GREETING CARD ': 34,
#  'PACK OF 12 SUKI TISSUES ': 272,
#  'PACK OF 12 WOODLAND TISSUES ': 196,
#  'PACK OF 12 SKULL TISSUES': 180,
#  'PACK OF 12 CIRCUS PARADE TISSUES ': 71,
#  'PACK OF 12 SPACEBOY TISSUES': 179,
#  'LADS ONLY TISSUE BOX': 116,
#  'RED RETROSPOT TISSUE BOX': 159,
#  'GINGERBREAD MAN COOKIE CUTTER': 574,
#  'GIN AND TONIC MUG': 203,
#  "IF YOU CAN'T STAND THE HEAT MUG": 95,
#  'I CAN ONLY PLEASE ONE PERSON MUG': 144,
#  'PINK HEART SHAPE EGG FRYING PAN': 209,
#  '200 RED + WHITE BENDY STRAWS': 122,
#  'RECIPE BOX RETROSPOT ': 476,
#  'RECIPE BOX PANTRY YELLOW DESIGN': 890,
#  'RECIPE BOX BLUE SKETCHBOOK DESIGN': 241,
#  '20 DOLLY PEGS RETROSPOT': 195,
#  'NO SINGING METAL SIGN': 392,
#  'BISCUIT TIN VINTAGE RED': 160,
#  'EMERGENCY FIRST AID TIN ': 126,
#  'POLKADOT PEN': 107,
#  'DECORATIVE PLANT POT WITH FRIEZE': 26,
#  'FRENCH BLUE METAL DOOR SIGN 5': 105,
#  'CHEST OF DRAWERS GINGHAM HEART ': 89,
#  'RED RETROSPOT CAKE STAND': 464,
#  'JOY WOODEN BLOCK LETTERS': 80,
#  'NOEL WOODEN BLOCK LETTERS ': 117,
#  'PEACE WOODEN BLOCK LETTERS': 111,
#  'OFFICE MUG WARMER BLACK+SILVER ': 102,
#  'SET OF 2 CHRISTMAS DECOUPAGE CANDLE': 97,
#  'COSMETIC BAG VINTAGE ROSE PAISLEY': 63,
#  'PINK ROSE FABRIC MIRROR': 25,
#  'SILVER PLATE CANDLE BOWL SMALL': 39,
#  'SMALL REGAL  SILVER CANDLEPOT ': 20,
#  'ANTIQUE TALL SWIRLGLASS TRINKET POT': 144,
#  'ANTIQUE GLASS PEDESTAL BOWL': 176,
#  'GUMBALL MAGAZINE RACK': 174,
#  'RED FLOWER CROCHET FOOD COVER': 91,
#  'CHERRY CROCHET FOOD COVER': 80,
#  'STRAWBERRY RAFFIA FOOD COVER': 97,
#  'POLKA DOT RAFFIA FOOD COVER': 73,
#  'DOORMAT SPOTTY HOME SWEET HOME': 413,
#  'T-LIGHT GLASS FLUTED ANTIQUE': 276,
#  'SILVER  CANDLEPOT JARDIN ': 9,
#  'POLKADOT MUG PINK ': 8,
#  'PAPER BUNTING COLOURED LACE': 174,
#  'ANTIQUE GLASS HEART DECORATION ': 31,
#  'SET OF 6 KASHMIR FOLKART BAUBLES': 75,
#  'CHRISTMAS RETROSPOT ANGEL WOOD': 157,
#  'CHRISTMAS RETROSPOT STAR WOOD': 148,
#  'HEART WOODEN CHRISTMAS DECORATION': 161,
#  'LARGE HANGING IVORY & RED WOOD BIRD': 67,
#  'SMALL HANGING IVORY/RED WOOD BIRD': 171,
#  'GRAND CHOCOLATECANDLE': 259,
#  'FAIRY CAKE BIRTHDAY CANDLE SET': 96,
#  '3 HOOK PHOTO SHELF ANTIQUE WHITE': 325,
#  'CREAM SWEETHEART WALL CABINET': 5,
#  'DOORMAT ENGLISH ROSE ': 361,
#  'DOORMAT UNION FLAG': 527,
#  'ROMANTIC IMAGES NOTEBOOK SET': 28,
#  'CURIOUS  IMAGES NOTEBOOK SET': 11,
#  'VINTAGE KEEPSAKE BOX PARIS DAYS': 6,
#  'RED GINGHAM ROSE JEWELLERY BOX': 233,
#  'BLUE CHARLIE+LOLA PERSONAL DOORSIGN': 94,
#  'CHARLIE+LOLA"EXTREMELY BUSY" SIGN': 73,
#  'CHARLOTTE BAG SUKI DESIGN': 611,
#  'LOLITA  DESIGN  COTTON TOTE BAG': 37,
#  'LETS GO SHOPPING COTTON TOTE BAG': 46,
#  'PAINT YOUR OWN CANVAS SET': 184,
#  'CAMOUFLAGE LED TORCH': 123,
#  'BLUE DRAGONFLY HELICOPTER': 36,
#  'YELLOW SHARK HELICOPTER': 39,
#  'RED SHARK HELICOPTER': 25,
#  'TOOL BOX SOFT TOY ': 85,
#  "DOCTOR'S BAG SOFT TOY": 68,
#  'CARRIAGE': 134,
#  'JUMBO BAG SCANDINAVIAN PAISLEY': 95,
#  'JUMBO BAG TOYS ': 254,
#  'SET OF SALT AND PEPPER TOADSTOOLS': 214,
#  'HOOK, 1 HANGER ,MAGIC GARDEN': 60,
#  'RED SPOTTY BISCUIT TIN': 217,
#  'PORCELAIN HANGING BELL SMALL': 1,
#  'PAINTED LIGHTBULB STAR+ MOON': 16,
#  'BLUE TEA TOWEL CLASSIC DESIGN': 48,
#  'SET 12 KIDS  WHITE CHALK STICKS': 191,
#  'CHRISTMAS MUSICAL ZINC STAR': 72,
#  'CHRISTMAS MUSICAL ZINC HEART ': 5,
#  'DOVE DECORATION PAINTED ZINC ': 54,
#  'UNION STRIPE WITH FRINGE  HAMMOCK': 169,
#  'FOLKART ZINC HEART CHRISTMAS DEC': 160,
#  'SKULLS AND CROSSBONES WRAP': 166,
#  'POLYESTER FILLER PAD 45x30cm': 37,
#  'POLYESTER FILLER PAD 40x40cm': 185,
#  'PINK FLOWER FABRIC PONY': 27,
#  'BIRTHDAY PARTY CORDON BARRIER TAPE': 82,
#  'CAMOUFLAGE DESIGN TEDDY': 36,
#  'TV DINNER TRAY AIR HOSTESS ': 66,
#  'SUKI  SHOULDER BAG': 206,
#  'BLUE SPOT CERAMIC DRAWER KNOB': 303,
#  'CUSHION COVER PINK UNION JACK': 37,
#  'CREAM SWEETHEART LETTER RACK': 25,
#  'FOUR HOOK  WHITE LOVEBIRDS': 271,
#  'FRENCH BLUE METAL DOOR SIGN 3': 105,
#  'FRENCH BLUE METAL DOOR SIGN No': 75,
#  'SET OF 3 BABUSHKA STACKING TINS': 16,
#  'BEACH HUT KEY CABINET': 10,
#  'SMALL PURPLE BABUSHKA NOTEBOOK ': 198,
#  'CHERRY BLOSSOM PASSPORT COVER': 25,
#  'SMALL YELLOW BABUSHKA NOTEBOOK ': 168,
#  'RETRO MOD TRAY': 113,
#  'SWEETHEART WIRE MAGAZINE RACK': 161,
#  'CARDHOLDER HOLLY WREATH METAL': 93,
#  'SILVER CHRISTMAS TREE BAUBLE STAND ': 25,
#  'SWEETHEART RECIPE BOOK STAND': 294,
#  'OVERNIGHT BAG VINTAGE ROSE PAISLEY': 90,
#  'ANT WHITE WIRE HEART SPIRAL': 65,
#  'FEATHER PEN,COAL BLACK': 118,
#  'FEATHER PEN,LIGHT PINK': 109,
#  'FEATHER PEN,HOT PINK': 162,
#  'DOORMAT AIRMAIL ': 159,
#  'NUMBER TILE COTTAGE GARDEN 8': 11,
#  'DOORMAT 3 SMILEY CATS': 178,
#  'BREAD BIN DINER STYLE IVORY': 371,
#  'BREAD BIN DINER STYLE RED ': 266,
#  'MAGNETS PACK OF 4 VINTAGE COLLAGE': 150,
#  'MAGNETS PACK OF 4 HOME SWEET HOME': 153,
#  'MAGNETS PACK OF 4 CHILDHOOD MEMORY': 89,
#  'ART LIGHTS,FUNK MONKEY': 48,
#  'MINI CAKE STAND WITH HANGING CAKES': 171,
#  'CERAMIC CAKE STAND + HANGING CAKES': 178,
#  'SWEETHEART CERAMIC TRINKET BOX': 415,
#  'SET OF 4 FAIRY CAKE PLACEMATS': 49,
#  'OFFICE MUG WARMER PINK': 57,
#  'OFFICE MUG WARMER CHOC+BLUE': 97,
#  'PLEASE ONE PERSON METAL SIGN': 723,
#  'GLITTER CHRISTMAS HEART ': 22,
#  'CIRCUS PARADE CHILDRENS EGG CUP ': 120,
#  'RED STRIPE CERAMIC DRAWER KNOB': 353,
#  'NURSERY A,B,C PAINTED LETTERS': 67,
#  'SET OF 2 ROUND TINS DUTCH CHEESE': 71,
#  'GREEN GEISHA GIRL ': 10,
#  'BLUE GEISHA GIRL ': 10,
#  'NEWSPAPER STAND': 3,
#  'CINAMMON & ORANGE WREATH': 35,
#  'LARGE WHITE HONEYCOMB PAPER BELL  ': 44,
#  'WOOD STOCKING CHRISTMAS SCANDISPOT': 105,
#  'SET OF 4 NAPKIN CHARMS HEARTS': 131,
#  'WOODEN TREE CHRISTMAS SCANDINAVIAN': 289,
#  'ROCKING HORSE GREEN CHRISTMAS ': 133,
#  'CHRISTMAS HANGING TREE WITH BELL': 91,
#  'JINGLE BELLS TREE DECORATION': 22,
#  'SET OF 4 NAPKIN CHARMS 3 KEYS ': 42,
#  'SET OF 4 NAPKIN CHARMS INSTRUMENT': 24,
#  'SET OF 4 NAPKIN CHARMS CROWNS ': 39,
#  'SWALLOW WOODEN CHRISTMAS DECORATION': 131,
#  'GLITTER CHRISTMAS TREE': 61,
#  'GARLAND WITH STARS AND BELLS': 43,
#  'CHRISTMAS GARLAND STARS,TREES': 22,
#  'SWISS CHALET TREE DECORATION ': 70,
#  'BIRD BOX CHRISTMAS TREE DECORATION': 5,
#  'WOODEN ADVENT CALENDAR CREAM': 98,
#  'Manual': 465,
#  'CARD MOTORBIKE SANTA': 180,
#  'CARD CHRISTMAS VILLAGE': 167,
#  'DOORMAT I LOVE LONDON': 69,
#  'WOOD AND GLASS MEDICINE CABINET': 10,
#  'MA CAMPAGNE CUTLERY BOX': 90,
#  'YULETIDE IMAGES GIFT WRAP SET': 60,
#  'WICKER WREATH LARGE': 130,
#  'TABLE LAMP WHITE SHADE WOOD BASE': 17,
#  'SMALL FOLKART STAR CHRISTMAS DEC': 34,
#  'SMALLFOLKART BAUBLE CHRISTMAS DEC': 8,
#  'SMALL HANGING GLASS+ZINC LANTERN': 9,
#  'SET/3 CHRISTMAS DECOUPAGE CANDLES': 33,
#  'PINK/WHITE CHRISTMAS TREE 60CM': 25,
#  'GREEN CHRISTMAS TREE STRING 20LIGHT': 11,
#  'EUCALYPTUS & PINECONE  WREATH': 39,
#  'CHRISTMAS PUDDING TRINKET POT ': 188,
#  'BLACK CHRISTMAS TREE 60CM': 22,
#  '15CM CHRISTMAS GLASS BALL 20 LIGHTS': 238,
#  'CARDHOLDER GINGHAM STAR': 58,
#  'WOODEN STAR CHRISTMAS SCANDINAVIAN': 456,
#  'FINE WICKER HEART ': 181,
#  'UNION JACK FLAG PASSPORT COVER ': 100,
#  'EDWARDIAN PARASOL PINK': 141,
#  'S/4 CACTI CANDLES': 86,
#  'PINK MARSHMALLOW SCARF KNITTING KIT': 1,
#  '6 CHOCOLATE LOVE HEART T-LIGHTS': 117,
#  'PINK BLUE FELT CRAFT TRINKET BOX': 473,
#  'TOAST ITS - BEST MUM': 70,
#  '3 TRADITIONAL COOKIE CUTTERS  SET': 4,
#  'CHILDRENS SPACEBOY MUG': 2,
#  'MIRRORED WALL ART SKULLS': 40,
#  'MIRRORED WALL ART STARS': 44,
#  'CHARLIE+LOLA PINK HOT WATER BOTTLE': 110,
#  'CHARLIE+LOLA RED HOT WATER BOTTLE ': 51,
#  'COWBOYS AND INDIANS BIRTHDAY CARD ': 203,
#  'RING OF ROSES BIRTHDAY CARD': 90,
#  'ALARM CLOCK BAKELIKE CHOCOLATE': 344,
#  'CERAMIC CAKE DESIGN SPOTTED MUG': 173,
#  'LIPSTICK PEN FUSCHIA': 124,
#  'BROCADE RING PURSE ': 212,
#  'GREEN 3 PIECE POLKADOT CUTLERY SET': 68,
#  'PAINTED METAL PEARS ASSORTED': 364,
#  'COLOUR GLASS. STAR T-LIGHT HOLDER': 248,
#  'SWALLOWS GREETING CARD': 245,
#  'LADLE LOVE HEART PINK': 3,
#  'LETTER "M" BLING KEY RING': 5,
#  'LETTER "V" BLING KEY RING': 3,
#  'LETTER "S" BLING KEY RING': 6,
#  'LETTER "J" BLING KEY RING': 5,
#  'WALL TIDY RETROSPOT ': 106,
#  'BINGO SET': 285,
#  'KIDS RAIN MAC PINK': 73,
#  'RED RETROSPOT CUP': 289,
#  'SQUARE FLOOR CUSHION VINTAGE RED': 27,
#  'SET/3 VANILLA SCENTED CANDLE IN BOX': 122,
#  'SET OF 2 TINS VINTAGE BATHROOM ': 60,
#  'BLUE  DIAMANTE PEN IN GIFT BOX': 23,
#  '36 PENCILS TUBE SKULLS': 186,
#  'GREEN FERN JOURNAL ': 37,
#  'RIBBON REEL FLORA + FAUNA ': 92,
#  'BLACK EAR MUFF HEADPHONES': 19,
#  'RED POLKADOT COFFEE  MUG': 49,
#  'EMPIRE UNION JACK TV DINNER TRAY': 80,
#  'ASSORTED TUTTI FRUTTI MIRROR': 32,
#  'SET OF 4 ROSE BOTANICAL CANDLES': 131,
#  'FELT EGG COSY BLUE RABBIT ': 51,
#  'LOVE HEART SOCK HANGER': 54,
#  'SCOTTIES CHILDRENS APRON': 10,
#  'CHILDS GARDEN BRUSH PINK': 65,
#  'LADYBIRD + BEE RAFFIA FOOD COVER': 33,
#  'HOME SWEET HOME MUG': 314,
#  'CHILDRENS GARDEN GLOVES BLUE': 66,
#  'CHRYSANTHEMUM SKETCHBOOK ': 53,
#  'BAG 250g SWIRLY MARBLES': 201,
#  'BAG 125g SWIRLY MARBLES': 252,
#  'ROSE 3 WICK MORRIS BOX CANDLE': 114,
#  'ROSE SCENT CANDLE JEWELLED DRAWER': 43,
#  'RED RETROSPOT CHILDRENS UMBRELLA': 189,
#  'WHITE BAMBOO RIBS LAMPSHADE': 52,
#  'FOLDING UMBRELLA CHOCOLATE POLKADOT': 31,
#  'CAKE STAND LOVEBIRD 2 TIER WHITE': 84,
#  '3 GARDENIA MORRIS BOXED CANDLES': 79,
#  'SET/4 GARDEN ROSE DINNER CANDLE': 3,
#  'GOLD PRINT PAPER BAG': 2,
#  'WOODEN HAPPY BIRTHDAY GARLAND': 236,
#  'SET/4 BADGES CUTE CREATURES': 24,
#  'BLUE PAISLEY POCKET BOOK': 51,
#  'PORCELAIN ROSE LARGE ': 13,
#  'PORCELAIN ROSE SMALL': 48,
#  'BAKING SET SPACEBOY DESIGN': 442,
#  'SOAP DISH BROCANTE': 97,
#  'FLUTED ANTIQUE CANDLE HOLDER': 131,
#  'PEACE SMALL WOOD LETTERS': 22,
#  'RED RETROSPOT APRON ': 114,
#  'TEA TIME KITCHEN APRON': 133,
#  'FELTCRAFT DOLL MARIA': 48,
#  'PARTY METAL SIGN ': 385,
#  'VINTAGE CREAM 3 BASKET CAKE STAND': 138,
#  'CHRISTMAS RETROSPOT HEART WOOD': 11,
#  'DOORMAT RESPECTABLE HOUSE': 128,
#  'MEMO BOARD RETROSPOT  DESIGN': 353,
#  'PINK/YELLOW FLOWERS HANDBAG': 8,
#  'CHARLIE+LOLA MY ROOM DOOR SIGN': 66,
#  'SALLE DE BAIN HOOK': 68,
#  'CHRISTMAS CARD STACK OF PRESENTS': 36,
#  'SET 12 KIDS COLOUR  CHALK STICKS': 289,
#  'SPACEBOY BIRTHDAY CARD': 398,
#  'ROBOT BIRTHDAY CARD': 262,
#  'JOY LARGE WOOD LETTERS': 14,
#  'WORLD WAR 2 GLIDERS ASSTD DESIGNS': 478,
#  'CHILDRENS APRON APPLES DESIGN': 284,
#  'ENCHANTED BIRD COATHANGER 5 HOOK': 197,
#  'TOAST ITS - FAIRY FLOWER': 55,
#  'CACTI T-LIGHT CANDLES': 135,
#  'HANGING BAUBLE T-LIGHT HOLDER SMALL': 21,
#  '12 PENCILS SMALL TUBE RED RETROSPOT': 319,
#  'BALLOON WATER BOMB PACK OF 35': 147,
#  'BALLOON PUMP WITH 10 BALLOONS': 118,
#  'ALPHABET STENCIL CRAFT': 171,
#  '3 TRADITIONAl BISCUIT CUTTERS  SET': 209,
#  'IVORY PAPER CUP CAKE CASES ': 66,
#  'PARTY INVITES WOODLAND': 93,
#  'PARTY INVITES BALLOON GIRL': 53,
#  'LOVELY BONBON STICKER SHEET': 35,
#  'SWEET PUDDING STICKER SHEET': 16,
#  'ASSTD DESIGN 3D PAPER STICKERS': 37,
#  'CUTE CATS TAPE': 45,
#  'TOOTHPASTE TUBE PEN': 77,
#  'MAGIC DRAWING SLATE PURDEY': 149,
#  'PACK OF 12 COLOURED PENCILS': 204,
#  'TOAST ITS - I LOVE YOU ': 114,
#  'BANK ACCOUNT  GREETING  CARD ': 17,
#  'EMPIRE BIRTHDAY CARD': 87,
#  'TEA PARTY BIRTHDAY CARD': 268,
#  'CARD CAT AND TREE ': 108,
#  'CARD DOG AND BALL ': 87,
#  'PENNY FARTHING BIRTHDAY CARD': 188,
#  'BLUE STRIPE CERAMIC DRAWER KNOB': 376,
#  'RED SPOT CERAMIC DRAWER KNOB': 298,
#  ...}

# %%
product=list(customer.keys())
count=list(customer.values())

# %%
data={'product' : product,
      'count' : count}

# %%
df1=pd.DataFrame.from_dict(data)

# %%
df1.head()
# Out:
#                                product  count
# 0   WHITE HANGING HEART T-LIGHT HOLDER   2070
# 1                  WHITE METAL LANTERN    259
# 2       CREAM CUPID HEARTS COAT HANGER    250
# 3  KNITTED UNION FLAG HOT WATER BOTTLE    330
# 4       RED WOOLLY HOTTIE WHITE HEART.    333

# %%
df1.sort_values(by=['count'],ascending=False)
# Out:
#                                  product  count
# 0     WHITE HANGING HEART T-LIGHT HOLDER   2070
# 533             REGENCY CAKESTAND 3 TIER   1905
# 140              JUMBO BAG RED RETROSPOT   1662
# 9          ASSORTED COLOUR BIRD ORNAMENT   1418
# 1398                       PARTY BUNTING   1416
# ...                                  ...    ...
# 3289   ANTIQUE RASPBERRY FLOWER EARRINGS      1
# 3736           WALL ART,ONLY ONE PERSON       1
# 3292     GOLD/AMBER DROP EARRINGS W LEAF      1
# 2655                INCENSE BAZAAR PEACH      1
# 1474    PINK BAROQUE FLOCK CANDLE HOLDER      1
#
# [3896 rows x 2 columns]

# %%
df.groupby('Description').agg(
    orders=('InvoiceNo', 'nunique'),
    quantity=('Quantity', 'sum')
).sort_values(by='orders', ascending=False).head(10)
# Out:
#                                     orders  quantity
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2013     34147
# REGENCY CAKESTAND 3 TIER              1884     11555
# JUMBO BAG RED RETROSPOT               1643     45066
# PARTY BUNTING                         1399     15027
# ASSORTED COLOUR BIRD ORNAMENT         1385     35314
# LUNCH BAG RED RETROSPOT               1329     17145
# SET OF 3 CAKE TINS PANTRY DESIGN      1218      6864
# POSTAGE                               1194      3002
# LUNCH BAG  BLACK SKULL.               1073     11173
# PACK OF 72 RETROSPOT CAKE CASES       1041     33409

# %%
df_baskets = df[['InvoiceNo', 'StockCode', 'Description', 'Quantity']]
df_baskets.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6

# %%
df_items = df_baskets.pivot_table(index='InvoiceNo', columns=['Description'], values='Quantity').fillna(0)
df_items.head(3)
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
# 536367                      0.0                           0.0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                0.0                       0.0
# 536366                                0.0                       0.0
# 536367                                0.0                       0.0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                               0.0                       0.0
# 536366                               0.0                       0.0
# 536367                               0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                    0.0                      0.0  ...
# 536366                                    0.0                      0.0  ...
# 536367                                    0.0                      0.0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                    0.0                             0.0
# 536366                                    0.0                             0.0
# 536367                                    0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                   0.0                              0.0
# 536366                                   0.0                              0.0
# 536367                                   0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                  0.0                               0.0
# 536366                                  0.0                               0.0
# 536367                                  0.0                               0.0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                               0.0                               0.0
# 536366                               0.0                               0.0
# 536367                               0.0                               0.0
#
# [3 rows x 3896 columns]

# %% [markdown]
# Recommendation Function

# %%
def get_recommendations(df, item):
    """Generate a set of product recommendations using item-based collaborative filtering.
    
    Args:
        df (dataframe): Pandas dataframe containing matrix of items purchased.
        item (string): Column name for target item. 
        
    Returns: 
        recommendations (dataframe): Pandas dataframe containing product recommendations. 
    """
    
    recommendations = df.corrwith(df[item])
    recommendations.dropna(inplace=True)
    recommendations = pd.DataFrame(recommendations, columns=['correlation']).reset_index()
    recommendations = recommendations.sort_values(by='correlation', ascending=False)
    
    return recommendations

# %%
recommendations = get_recommendations(df_items, 'WHITE HANGING HEART T-LIGHT HOLDER')
recommendations.head()
# Out:
#                              Description  correlation
# 3716  WHITE HANGING HEART T-LIGHT HOLDER     1.000000
# 1396         GIN + TONIC DIET METAL SIGN     0.825321
# 1168  FAIRY CAKE FLANNEL ASSORTED COLOUR     0.821271
# 1018                  DOORMAT FAIRY CAKE     0.483746
# 3436              TEA TIME PARTY BUNTING     0.469531

# %%
recommendations = get_recommendations(df_items, 'PARTY BUNTING')
recommendations.head()
# Out:
#                              Description  correlation
# 2355                       PARTY BUNTING     1.000000
# 3338                      SPOTTY BUNTING     0.258734
# 33    18PC WOODEN CUTLERY SET DISPOSABLE     0.178650
# 110        6PC WOOD PLATE SET DISPOSABLE     0.169431
# 3376        STRAWBERRY RAFFIA FOOD COVER     0.134040

# %%
recommendations = get_recommendations(df_items, 'LETTER "M" BLING KEY RING')
recommendations.head()
# Out:
#                     Description  correlation
# 1900  LETTER "M" BLING KEY RING     1.000000
# 1895  LETTER "H" BLING KEY RING     0.873071
# 1897  LETTER "J" BLING KEY RING     0.871016
# 1908  LETTER "V" BLING KEY RING     0.789548
# 1911  LETTER "Z" BLING KEY RING     0.789536

# %%
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([0, 3, 2, ..., 0, 2, 2])

# %%
kmeans = KMeans(n_clusters=3, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=3)

# %%
 kmeans.labels_
# Out:
# array([1, 2, 0, ..., 1, 0, 0])

# %%
rfm['Cluster_Id'] = kmeans.labels_
rfm.head()
# Out:
#   CustomerID   Amount  Frequency  Recency  Cluster_Id
# 0    12346.0     0.00          2      325           1
# 1    12347.0  4310.00        182        1           2
# 2    12348.0  1797.24         31       74           0
# 3    12349.0  1757.55         73       18           0
# 4    12350.0   334.40         17      309           1

# %%
sns.boxplot(x='Cluster_Id', y='Amount', data=rfm)
# Out:
# <AxesSubplot:xlabel='Cluster_Id', ylabel='Amount'>

# %%
sns.boxplot(x='Cluster_Id', y='Frequency', data=rfm)
# Out:
# <AxesSubplot:xlabel='Cluster_Id', ylabel='Frequency'>

# %% [markdown]
# 5.Dendrograms

# %%
mergings = linkage(rfm_df_scaled, method="single", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
mergings = linkage(rfm_df_scaled, method="complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
trimmed_df = df.copy()

# %%
trimmed_df.to_csv("Retail_Cluster_Output.csv", index=False)

# %%
rfm.to_csv("Cluster_Summary.csv",index=False)

# %%
#summary_df.to_csv("Business_Summary.csv")

# %%
#summary_df

# %% [raw]
# no_of_customers = trimmed_df['CustomerID'].nunique()
# no_of_countries = trimmed_df['Country'].nunique()
# no_of_completed_transactions = Completed['Frequency'].sum()
# amount_completed = Completed['Amount'].sum()
# no_of_cancelled_transactions = Cancelled['Frequency'].sum()
# amount_cancelled = Cancelled['Amount'].sum()
#
# summary_df = pd.DataFrame({
#     'Metric' : [
#         'Total Customers',
#         'Total Countries',
#         'Completed Transactions',
#         'Completed Amount',
#         'Cancelled Transactions',
#         'Cancelled Amount'
#     ],
#     'value':[
#         no_of_customers,
#         no_of_countries,
#         no_of_completed_transactions,
#         amount_completed,
#         no_of_cancelled_transactions,
#         amount_cancelled
#     ]
# })
#
# summary_df

# %%
#no_of_customers

# %%
retail=pd.read_csv('Retail_Cluster_Output.csv')
summary=pd.read_csv('Cluster_Summary.csv')

# Merge on the common column
result = pd.merge(
    retail,
    summary,
    on='CustomerID',
    how='left'
)

# Save the result
result.to_csv('Merged_Output.csv',index=False)

print(result.head())
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0     17850.0    536365    85123A         6       2.55  15.30
# 1     17850.0    536365     71053         6       3.39  20.34
# 2     17850.0    536365    84406B         8       2.75  22.00
# 3     17850.0    536365    84029G         6       3.39  20.34
# 4     17850.0    536365    84029E         6       3.39  20.34
#
#                            Description          InvoiceDate         Country  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2010-12-01 08:26:00  United Kingdom
# 1                  WHITE METAL LANTERN  2010-12-01 08:26:00  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER  2010-12-01 08:26:00  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  2010-12-01 08:26:00  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART.  2010-12-01 08:26:00  United Kingdom
#
#    year  Totalamt               Diff   Amount  Frequency  Recency  Cluster_Id
# 0  2010     15.30  373 days 04:24:00  5288.63      312.0    301.0         2.0
# 1  2010     20.34  373 days 04:24:00  5288.63      312.0    301.0         2.0
# 2  2010     22.00  373 days 04:24:00  5288.63      312.0    301.0         2.0
# 3  2010     20.34  373 days 04:24:00  5288.63      312.0    301.0         2.0
# 4  2010     20.34  373 days 04:24:00  5288.63      312.0    301.0         2.0

# %%
retail.head()
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0     17850.0    536365    85123A         6       2.55  15.30
# 1     17850.0    536365     71053         6       3.39  20.34
# 2     17850.0    536365    84406B         8       2.75  22.00
# 3     17850.0    536365    84029G         6       3.39  20.34
# 4     17850.0    536365    84029E         6       3.39  20.34
#
#                            Description          InvoiceDate         Country  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2010-12-01 08:26:00  United Kingdom
# 1                  WHITE METAL LANTERN  2010-12-01 08:26:00  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER  2010-12-01 08:26:00  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  2010-12-01 08:26:00  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART.  2010-12-01 08:26:00  United Kingdom
#
#    year  Totalamt               Diff
# 0  2010     15.30  373 days 04:24:00
# 1  2010     20.34  373 days 04:24:00
# 2  2010     22.00  373 days 04:24:00
# 3  2010     20.34  373 days 04:24:00
# 4  2010     20.34  373 days 04:24:00

# %%
summary.head()
# Out:
#    CustomerID   Amount  Frequency  Recency  Cluster_Id
# 0     12346.0     0.00          2      325           1
# 1     12347.0  4310.00        182        1           2
# 2     12348.0  1797.24         31       74           0
# 3     12349.0  1757.55         73       18           0
# 4     12350.0   334.40         17      309           1

# %%
import pandas as pd

# Read the files
retail = pd.read_csv("Retail_Cluster_Output.csv")
summary = pd.read_csv("Cluster_Summary.csv")

# Merge on CustomerID
merged_df = retail.merge(
    summary[['CustomerID', 'Cluster_Id']],   # or use summary to include all columns
    on='CustomerID',
    how='left'
)

# Display the DataFrame
print(merged_df.head())
# Out:
#    CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0     17850.0    536365    85123A         6       2.55  15.30
# 1     17850.0    536365     71053         6       3.39  20.34
# 2     17850.0    536365    84406B         8       2.75  22.00
# 3     17850.0    536365    84029G         6       3.39  20.34
# 4     17850.0    536365    84029E         6       3.39  20.34
#
#                            Description          InvoiceDate         Country  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2010-12-01 08:26:00  United Kingdom
# 1                  WHITE METAL LANTERN  2010-12-01 08:26:00  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER  2010-12-01 08:26:00  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  2010-12-01 08:26:00  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART.  2010-12-01 08:26:00  United Kingdom
#
#    year  Totalamt               Diff  Cluster_Id
# 0  2010     15.30  373 days 04:24:00         2.0
# 1  2010     20.34  373 days 04:24:00         2.0
# 2  2010     22.00  373 days 04:24:00         2.0
# 3  2010     20.34  373 days 04:24:00         2.0
# 4  2010     20.34  373 days 04:24:00         2.0

# %%
merged_df
# Out:
#         CustomerID InvoiceNo StockCode  Quantity  UnitPrice  Total  \
# 0          17850.0    536365    85123A         6       2.55  15.30
# 1          17850.0    536365     71053         6       3.39  20.34
# 2          17850.0    536365    84406B         8       2.75  22.00
# 3          17850.0    536365    84029G         6       3.39  20.34
# 4          17850.0    536365    84029E         6       3.39  20.34
# ...            ...       ...       ...       ...        ...    ...
# 406824     12680.0    581587     22613        12       0.85  10.20
# 406825     12680.0    581587     22899         6       2.10  12.60
# 406826     12680.0    581587     23254         4       4.15  16.60
# 406827     12680.0    581587     23255         4       4.15  16.60
# 406828     12680.0    581587     22138         3       4.95  14.85
#
#                                 Description          InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER  2010-12-01 08:26:00
# 1                       WHITE METAL LANTERN  2010-12-01 08:26:00
# 2            CREAM CUPID HEARTS COAT HANGER  2010-12-01 08:26:00
# 3       KNITTED UNION FLAG HOT WATER BOTTLE  2010-12-01 08:26:00
# 4            RED WOOLLY HOTTIE WHITE HEART.  2010-12-01 08:26:00
# ...                                     ...                  ...
# 406824          PACK OF 20 SPACEBOY NAPKINS  2011-12-09 12:50:00
# 406825         CHILDREN'S APRON DOLLY GIRL   2011-12-09 12:50:00
# 406826        CHILDRENS CUTLERY DOLLY GIRL   2011-12-09 12:50:00
# 406827      CHILDRENS CUTLERY CIRCUS PARADE  2011-12-09 12:50:00
# 406828        BAKING SET 9 PIECE RETROSPOT   2011-12-09 12:50:00
#
#                Country  year  Totalamt               Diff  Cluster_Id
# 0       United Kingdom  2010     15.30  373 days 04:24:00         2.0
# 1       United Kingdom  2010     20.34  373 days 04:24:00         2.0
# 2       United Kingdom  2010     22.00  373 days 04:24:00         2.0
# 3       United Kingdom  2010     20.34  373 days 04:24:00         2.0
# 4       United Kingdom  2010     20.34  373 days 04:24:00         2.0
# ...                ...   ...       ...                ...         ...
# 406824          France  2011     10.20    0 days 00:00:00         0.0
# 406825          France  2011     12.60    0 days 00:00:00         0.0
# 406826          France  2011     16.60    0 days 00:00:00         0.0
# 406827          France  2011     16.60    0 days 00:00:00         0.0
# 406828          France  2011     14.85    0 days 00:00:00         0.0
#
# [406829 rows x 13 columns]
